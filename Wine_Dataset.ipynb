# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('winedataset.csv')
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
#lets check null values
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
sns.heatmap(df.corr())

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
#lets check skewness
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %%
#change the values in each columns by replacing log1 values
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.529222
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.605723
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.097222
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.087930
# dtype: float64

# %%
#still showing more than 0.55 in Mangesium column so again applying to reduce skewness
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.529222
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.527327
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.097222
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.087930
# dtype: float64

# %%
#lets check relation between columns
sns.pairplot(df)
plt.show()

# %%
#lets check for the outliers
from scipy.stats import zscore
z_score = abs(zscore(df))
print(df.shape)
df_final = df.loc[(z_score<3).all(axis=1)]
print(df_final.shape)
# Out:
# (178, 14)
# (170, 14)

# %%
#lets separate x and y
df_x = df_final.drop(columns=["Proline    "],axis=1)
y = df_final[["Proline    "]]

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
#lets do standard scaling to scaled a data at one stage as it is going to be trained on linear regression model
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(df_x)
x = pd.DataFrame(x, columns=df_x.columns)

# %%
#lets again check the skewness
X.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.529222
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.527327
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.097222
# Hue                     0.021091
# diluted wines          -0.307285
# dtype: float64

# %%
#lets split the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=50,test_size=0.30)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn import linear_model
maxr_score = 0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=r_state,test_size=0.30)
    regr = linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    if r2_scr > maxr_score:
        maxr_score = r2_scr
        final_r_state = r_state
print("max r2 corrosponding to ",final_r_state," is ",maxr_score)
# Out:
# max r2 corrosponding to  53  is  0.7806694048015046

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(regr,x,y,cv=10,scoring="r2").mean()
# Out:
# -0.3066807396994348

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=53,test_size=0.30)
lregr = linear_model.LinearRegression()
lregr.fit(x_train,y_train)
y_pred = regr.predict(x_test)

# %%
print("r2 score is :", r2_score(y_test,y_pred))
print("RMSE is :" , np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is : 0.7806694048015046
# RMSE is : 0.17738812561738979

# %%
#lets save the model
from sklearn.externals import joblib

joblib.dump(lregr, 'wine.pkl')
# Out:
# ['wine.pkl']
